# %% [markdown]
# http://www.idlcoyote.com/ip_tips/sharpen.html
#
# http://fourier.eng.hmc.edu/e161/lectures/gradient/node1.html to-read

# %%
import numpy as np
% matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
import cv2 as cv
img = cv.imread('./data/stones.jpg',0)
plt.figure()
plt.title('Original')
imshow(img,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from scipy import ndimage
# Lablasian Filters
lablas=np.array([[-1,-1,-1],
                 [-1, 8,-1],
                 [-1,-1,-1]])
filtered=ndimage.convolve(img,lablas)
plt.figure()
plt.subplot(1,2,1)
plt.title('After filtering')
imshow(filtered,cmap='gray')
filtered=255*(filtered-filtered.min())/filtered.max()
plt.subplot(1,2,2)
plt.title('After filtering and normalization')
imshow(filtered,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="796">

# %%
sharpened = img + filtered
sharpened = 255*((sharpened-sharpened.min())/sharpened.max())
imshow(sharpened,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">
